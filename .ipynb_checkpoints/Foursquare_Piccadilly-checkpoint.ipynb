# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
{
    "tags": [
        "hidecode",
    ]
}
CLIENT_ID = 'DHVNUJV5I1ISC4NZWFCINPJNV2VVKHRO3N4K2IKAIPPWP0NC' # your Foursquare ID
CLIENT_SECRET = '2Q3TY50TJLOZK4FJHDEGIHG0MHVDQTNVK2ZPKOXJGNRVX2B1' # your Foursquare Secret
VERSION = '20190414'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DHVNUJV5I1ISC4NZWFCINPJNV2VVKHRO3N4K2IKAIPPWP0NC
# CLIENT_SECRET:2Q3TY50TJLOZK4FJHDEGIHG0MHVDQTNVK2ZPKOXJGNRVX2B1

# %% [markdown]
# #### Let's again assume that you are staying at the Piccadilly Circus (London). So let's start by converting the Piccadilly Circus's address to its latitude and longitude coordinates.

# %%
address = '34 Haymarket, St. James\'s, London W1D 7AD'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 51.5099408 -0.1328618

# %% [markdown]
# ## 1. Search for a specific venue category
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# ### Now, let's assume that it is lunch time, and you are craving any food. So, let's define a query to search for Italian food that is within 500 metres from the Piccadilly Circus.

# %%
search_query = 'Restaurant'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %% [markdown]
# ### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DHVNUJV5I1ISC4NZWFCINPJNV2VVKHRO3N4K2IKAIPPWP0NC&client_secret=2Q3TY50TJLOZK4FJHDEGIHG0MHVDQTNVK2ZPKOXJGNRVX2B1&ll=51.5099408,-0.1328618&v=20190414&query=Restaurant&radius=500&limit=30'

# %% [markdown]
# ### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cb358b39fb6b77733cbf549'},
#  'response': {'venues': [{'id': '5001b8e6e4b05e79b0b3b84d',
#     'name': "Bill's Restaurant",
#     'location': {'address': '36-44 Brewer St',
#      'crossStreet': 'Lexington St',
#      'lat': 51.51183377093123,
#      'lng': -0.13508045829141016,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51183377093123,
#        'lng': -0.13508045829141016}],
#      'distance': 260,
#      'postalCode': 'W1F 9TB',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['36-44 Brewer St (Lexington St)',
#       'Soho',
#       'Greater London',
#       'W1F 9TB',
#       'United Kingdom']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a05',
#       'name': 'English Restaurant',
#       'pluralName': 'English Restaurants',
#       'shortName': 'English',
# ...

# %% [markdown]
# ### Get relevant part of JSON and transform it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                                                                                                                                                                                                                        categories  \
# 0  [{'id': '52e81612bcbc57f1066b7a05', 'name': 'English Restaurant', 'pluralName': 'English Restaurants', 'shortName': 'English', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}]
# 1  [{'id': '4bf58dd8d48988d156941735', 'name': 'Malay Restaurant', 'pluralName': 'Malay Restaurants', 'shortName': 'Malay', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/malaysian_', 'suffix': '.png'}, 'primary': True}]
# 2  [{'id': '52e81612bcbc57f1066b7a05', 'name': 'English Restaurant', 'pluralName': 'English Restaurants', 'shortName': 'English', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}]
# ...

# %% [markdown]
# ### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                        name            categories  \
# 0   Bill's Restaurant                        English Restaurant
# 1   C&R Café Restaurant                      Malay Restaurant
# 2   The Ivy Restaurant                       English Restaurant
# 3   Bill's Restaurant                        English Restaurant
# 4   London Chinatown Restaurant              Chinese Restaurant
# 5   Portrait Restaurant                      Café
# 6   Hung's Chinese Restaurant | 美食軒          Chinese Restaurant
# 7   Kowloon Restaurant and Cakeshop          Chinese Restaurant
# 8   New Loon Fung Chinese Restaurant         Chinese Restaurant
# 9   The Restaurant At Royal Academy Of Arts  Restaurant
# 10  Ham Yard Bar & Restaurant                Bar
# 11  Woodlands Restaurant                     Indian Restaurant
# 12  JinLi Restaurant                         Szechuan Restaurant
# 13  Chinatown                                Neighborhood
# ...

# %% [markdown]
# ### Let's visualize the Italian restaurants that are nearby

# %%
dataframe_filtered.name
# Out:
# 0     Bill's Restaurant
# 1     C&R Café Restaurant
# 2     The Ivy Restaurant
# 3     Bill's Restaurant
# 4     London Chinatown Restaurant
# 5     Portrait Restaurant
# 6     Hung's Chinese Restaurant | 美食軒
# 7     Kowloon Restaurant and Cakeshop
# 8     New Loon Fung Chinese Restaurant
# 9     The Restaurant At Royal Academy Of Arts
# 10    Ham Yard Bar & Restaurant
# 11    Woodlands Restaurant
# 12    JinLi Restaurant
# 13    Chinatown
# 14    Blue Garden Restaurant
# 15    Rooftop Bar & Restaurant
# 16    Joy Luck Restaurant
# 17    Royal Court Restaurant
# 18    Vespa Italian Restaurant
# 19    翠亨邨酒家 London Chinatown Restaurant
# 20    Dishoom
# 21    St Moritz Restaurant
# 22    Canton Restaurant
# 23    Refuel Bar & Restaurant
# 24    LIKO Korean & Japanese Restaurant
# 25    JunKie Restaurant
# 26    Okuroğlu Restaurant
# 27    Michael Caines restaurant
# 28    Mitsukoshi Restaurant
# 29    Misato
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around Piccadilly Circus

# add a red circle marker to represent the Piccadilly Circus
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 2. Explore a Given Venue
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### Let's explore Dishoom

# %%
venue_id = '4c31c371a0ced13a150d146e' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4c31c371a0ced13a150d146e?client_id=DHVNUJV5I1ISC4NZWFCINPJNV2VVKHRO3N4K2IKAIPPWP0NC&client_secret=2Q3TY50TJLOZK4FJHDEGIHG0MHVDQTNVK2ZPKOXJGNRVX2B1&v=20190414'

# %% [markdown]
# ### Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'storeId', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4c31c371a0ced13a150d146e',
#  'name': 'Dishoom',
#  'contact': {'phone': '+442074209320',
#   'formattedPhone': '+44 20 7420 9320',
#   'twitter': 'dishoom',
#   'instagram': 'dishoom',
#   'facebook': '109165852443238',
#   'facebookUsername': 'dishoomlondon',
#   'facebookName': 'Dishoom'},
#  'location': {'address': '12 Upper St Martin’s Ln',
#   'lat': 51.51243,
#   'lng': -0.12690805,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 51.51243,
#     'lng': -0.12690805}],
#   'postalCode': 'WC2H 9FB',
#   'cc': 'GB',
# ...

# %% [markdown]
# ### B. Get the venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.4

# %% [markdown]
# ### C. Get the number of tips

# %%
result['response']['venue']['tips']['count']
# Out:
# 722

# %% [markdown]
# ### D. Get the venue's tips
#
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`/tips?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**`&limit=`**LIMIT**

# %%
## Dishoom Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cb35912f594df78c1cc1611'},
#  'response': {'tips': {'count': 722,
#    'items': [{'id': '54457d51498ecaa2143aaed5',
#      'createdAt': 1413840209,
#      'text': 'The waiter is so cute that they brought a dice for you to roll When you get your check, and if u get the number 6 the meal is on them! Chicken curry , chicken tikka with black daal is so yummy.',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/54457d51498ecaa2143aaed5',
#      'photo': {'id': '54457d5311d28625479a3969',
#       'createdAt': 1413840211,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/96748205_0a_hnsifsPB5-zhyaLbSKGVDU8pmyr0nU4pS0b1PM5I.jpg',
#       'width': 960,
#       'height': 720,
#       'visibility': 'public'},
# ...

# %% [markdown]
# #### Get tips and list of associated features

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'photo', 'photourl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'lastVoteText', 'lastUpvoteTimestamp', 'todo', 'user'])

# %% [markdown]
# #### Format column width and display all tips

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                                                                                                        text  \
# 0  The waiter is so cute that they brought a dice for you to roll When you get your check, and if u get the number 6 the meal is on them! Chicken curry , chicken tikka with black daal is so yummy.
# 1  Don't worry if you are in an hour long queue for this place. That's a usual peaktime wait for dinner. The staff are nice & will hand out free chai tea & spicy crackers, or put heaters on in the winter
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  16          0              54457d51498ecaa2143aaed5  Aurora
# 1  15          0              59b314b82d2fd96a669df961  Matt
#
#   user.lastName user.gender   user.id
# 0  Young         female      96748205
# 1  Ta-Min        male        98683884

# %% [markdown]
# ## 3. Search a Foursquare User
# > `https://api.foursquare.com/v2/users/`**USER_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### Define URL, send GET request and display features associated with use

# %%
user_id = '96748205' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/users/{}?client_id={}&client_secret={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
user_data = results['response']['user']

# display features associated with user
user_data.keys()
# Out:
# dict_keys(['id', 'firstName', 'lastName', 'gender', 'canonicalUrl', 'photo', 'friends', 'tips', 'homeCity', 'bio', 'contact', 'photos', 'type', 'mayorships', 'checkins', 'lists', 'lenses'])

# %%
print('First Name: ' + user_data['firstName'])
print('Last Name: ' + user_data['lastName'])
print('Home City: ' + user_data['homeCity'])
# Out:
# First Name: Aurora
# Last Name: Young
# Home City: Belmont California

# %% [markdown]
# #### How many tips has this user submitted?

# %%
user_data['tips']
# Out:
# {'count': 65}

# %% [markdown]
# ### Get User's tips

# %%
# define tips URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
#                                                                                                                                                                                                        text  \
# 0   try their hand pulled noodle, everything else is only so so. The hand pulled beef noodle soup is delicious .
# 1   Beautiful garden with Rodin sculpture , nice collection of classic paintings .
# 2   Very modern, conceptual and contemporary.
# 3   Great museum if you are into human and earth history and paleontology
# 4   It's a fast food place , we were in a hurry and had low expectations but the chicken katsu curry was surprisingly good! Shrimp tempura udon broth tastes weird.
# 5   Can't go wrong with frois gras in Lyon. veal was really tasty and my chicken was delicious too, a bit on the heavy creamy side. I had the waiter put less cream on my plate.one of bocuse's restaurant.
# 6   Love the view!
# ...

# %% [markdown]
# ### Let's get the venue for the tip with the greatest number of agree counts

# %%
tip_id = '563fd635cd10af639223b51b' # tip id

# define URL
url = 'http://api.foursquare.com/v2/tips/{}?client_id={}&client_secret={}&v={}'.format(tip_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tip']['venue']['name'])
print(result['response']['tip']['venue']['location'])
# Out:
# Musée des Beaux-Arts
# {'address': '20 Place des Terreaux', 'lat': 45.76677154225662, 'lng': 4.833712168177134, 'labeledLatLngs': [{'label': 'display', 'lat': 45.76677154225662, 'lng': 4.833712168177134}], 'postalCode': '69001', 'cc': 'FR', 'city': 'Lyon', 'state': 'Rhône-Alpes', 'country': 'France', 'formattedAddress': ['20 Place des Terreaux', '69001 Lyon', 'France']}

# %% [markdown]
# #### Get User's friends

# %%
user_friends = json_normalize(user_data['friends']['groups'][0]['items'])
user_friends
# Out:
#   bio firstName  gender           homeCity        id lastName  \
# 0      CoCo      female  San Francisco, CA  73567322  Pai
# 1      Jhon      male                       96616528  Kong
# 2      Sandy     female  New York, NY       6017      Lin
# 3      NiNi      female  San Mateo          5480922   T
# 4      Caroline  female  Foster city, CA    916616    Bush
# 5      Jennifer  female  San Francisco, CA  50225477  NaN
# 6      Stef      female  San Francisco, CA  917497    Y
# 7      Steven    male    Seattle, WA        371994    Chew
# 8      Melody    female  New York, NY       753308    Koh
# 9      Wendy     female  New York, NY       65049831  Ouyang
#
#                                       lists.groups  \
# 0  [{'type': 'created', 'count': 3, 'items': []}]
# 1  [{'type': 'created', 'count': 2, 'items': []}]
# 2  [{'type': 'created', 'count': 6, 'items': []}]
# 3  [{'type': 'created', 'count': 2, 'items': []}]
# 4  [{'type': 'created', 'count': 2, 'items': []}]
# ...

# %% [markdown]
# ### Retrieve the User's Profile Image

# %%
user_data
# Out:
# {'id': '96748205',
#  'firstName': 'Aurora',
#  'lastName': 'Young',
#  'gender': 'female',
#  'canonicalUrl': 'https://foursquare.com/user/96748205',
#  'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#   'suffix': '/96748205-5GAMT0THAF41YPLU.jpg'},
#  'friends': {'count': 12,
#   'groups': [{'type': 'others',
#     'name': 'Other friends',
#     'count': 12,
#     'items': [{'id': '73567322',
#       'firstName': 'CoCo',
#       'lastName': 'Pai',
#       'gender': 'female',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/73567322_8HNEDU3V_Q9C_Nna6ZTWFPfFBu19jXcmsVvoo5r3YVoLtYtPP1XJG4e6N_GcKlrhECNdEIQJZ.jpg'},
#       'tips': {'count': 0},
#       'lists': {'groups': [{'type': 'created', 'count': 3, 'items': []}]},
#       'homeCity': 'San Francisco, CA',
#       'bio': '',
#       'contact': {}},
#      {'id': '96616528',
#       'firstName': 'Jhon',
#       'lastName': 'Kong',
#       'gender': 'male',
# ...

# %%
# 1. grab prefix of photo
# 2. grab suffix of photo
# 3. concatenate them using the image size  
Image(url='https://fastly.4sqi.net/img/user/300x300/96748205-5GAMT0THAF41YPLU.jpg')
# Out:
# <img src="https://fastly.4sqi.net/img/user/300x300/96748205-5GAMT0THAF41YPLU.jpg"/>

# %% [markdown]
# ## 4. Explore a location
# > `https://api.foursquare.com/v2/venues/`**explore**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### So, you just finished your gourmet dish at Dishoom, and are just curious about the popular spots around the restaurant. In order to explore the area, let's start by getting the latitude and longitude values of Dishoom.

# %%
latitude = 51.51243
longitude = -0.12690805

# %% [markdown]
# #### Define URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=DHVNUJV5I1ISC4NZWFCINPJNV2VVKHRO3N4K2IKAIPPWP0NC&client_secret=2Q3TY50TJLOZK4FJHDEGIHG0MHVDQTNVK2ZPKOXJGNRVX2B1&ll=51.51243,-0.12690805&v=20190414&radius=500&limit=30'

# %% [markdown]
# #### Send GET request and examine results

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around Dishoom restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Dishoom restaurant.'

# %% [markdown]
# #### Get relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4c31c371a0ced13a150d146e',
#   'name': 'Dishoom',
#   'location': {'address': '12 Upper St Martin’s Ln',
#    'lat': 51.51243,
#    'lng': -0.12690805,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 51.51243,
#      'lng': -0.12690805}],
#    'distance': 0,
#    'postalCode': 'WC2H 9FB',
#    'cc': 'GB',
#    'neighborhood': 'City of Westminster',
#    'city': 'Covent Garden',
#    'state': 'Greater London',
#    'country': 'United Kingdom',
#    'formattedAddress': ['12 Upper St Martin’s Ln',
#     'Covent Garden',
#     'Greater London',
#     'WC2H 9FB',
#     'United Kingdom']},
#   'categories': [{'id': '4bf58dd8d48988d10f941735',
#     'name': 'Indian Restaurant',
#     'pluralName': 'Indian Restaurants',
#     'shortName': 'Indian',
# ...

# %% [markdown]
# ### Process JSON and convert it to a clean dataframe

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                                                     name  \
# 0  Dishoom
# 1  Hawksmoor Seven Dials
# 2  Fabrique
# 3  Amorino
# 4  Udderlicious
# 5  London Graphic Centre
# 6  Pineapple Dance Studios
# 7  La Gelatiera
# 8  Harry Potter and the Cursed Child - Parts One and Two
# 9  Seven Dials
#
#               categories                  address  cc           city  \
# 0  Indian Restaurant      12 Upper St Martin’s Ln  GB  Covent Garden
# 1  Steakhouse             11 Langley St            GB  London
# 2  Bakery                 8 Earlham St             GB  NaN
# 3  Ice Cream Shop         7 Garrick St             GB  London
# 4  Ice Cream Shop         24 Earlham St            GB  London
# 5  Arts & Crafts Store    16-18 Shelton St         GB  Covent Garden
# 6  Dance Studio           7 Langley St             GB  London
# 7  Ice Cream Shop         27 New Row               GB  London
# 8  General Entertainment  109-113 Shaftesbury Ave  GB  London
# ...

# %% [markdown]
# #### Let's visualize these items on the map around our location

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5. Explore Trending Venues
# > `https://api.foursquare.com/v2/venues/`**trending**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**

# %% [markdown]
# #### Now, instead of simply exploring the area around 4D Caffetteria Italiana, you are interested in knowing the venues that are trending at the time you are done with your lunch, meaning the places with the highest foot traffic. So let's do that and get the trending venues around 4D Caffetteria Italiana.

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cb35b0f6a60715adc8d830d'},
#  'response': {'venues': [{'id': '4c52b7a4b6dabe9a24d2bb13',
#     'name': 'Covent Garden',
#     'location': {'lat': 51.511958,
#      'lng': -0.122729,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.511958,
#        'lng': -0.122729}],
#      'distance': 294,
#      'postalCode': 'W C2E',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London',
#       'Greater London',
#       'W C2E',
#       'United Kingdom']},
#     'categories': [{'id': '4f2a25ac4b909258e854f55f',
#       'name': 'Neighborhood',
#       'pluralName': 'Neighborhoods',
#       'shortName': 'Neighborhood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'primary': True}]},
#    {'id': '4ac518d2f964a5203da720e3',
#     'name': 'British Museum',
# ...

# %% [markdown]
# ### Check if any venues are trending at this time

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
#               name         categories  location.distance  location.city  \
# 0  Covent Garden    Neighborhood       294                London
# 1  British Museum   History Museum     730                London
# 2  Selfridges & Co  Department Store   1814               London
# 3  Ladurée          Dessert Shop       257                London
# 4  Masala Zone      Indian Restaurant  290                Covent Garden
#
#   location.postalCode  location.state location.country  location.lat  \
# 0  W C2E               Greater London  United Kingdom   51.511958
# 1  WC1B 3DG            Greater London  United Kingdom   51.518988
# 2  W1A 1AB             Greater London  United Kingdom   51.514640
# 3  WC2E 8RA            Greater London  United Kingdom   51.512014
# 4  WC2E 9DA            Greater London  United Kingdom   51.513253
#
#    location.lng
# 0 -0.122729
# 1 -0.126510
# 2 -0.152864
# 3 -0.123256
# 4 -0.122922

# %% [markdown]
# ### Visualize trending venues

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Dishoom',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
